# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications import VGG19
import os

# %%
disease_types=['COVID', 'non-COVID']
data_dir = r"C:\Users\chanu\Desktop\covid images"
train_dir = os.path.join(data_dir)

train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])      
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.head()
# Out:
#                      File  DiseaseID Disease Type
# 0     COVID/Covid (1).png          0        COVID
# 1    COVID/Covid (10).png          0        COVID
# 2   COVID/Covid (100).png          0        COVID
# 3  COVID/Covid (1000).png          0        COVID
# 4  COVID/Covid (1001).png          0        COVID

# %%
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                             File  DiseaseID Disease Type
# 0         COVID/Covid (1227).png          0        COVID
# 1          COVID/Covid (430).png          0        COVID
# 2  non-COVID/Non-Covid (322).png          1    non-COVID
# 3  non-COVID/Non-Covid (379).png          1    non-COVID
# 4          COVID/Covid (609).png          0        COVID

# %%
plt.hist(train['DiseaseID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
 # Displays first n images of class from training set
plot_defects('COVID', 5, 5)

# %%
# Displays first n images of class from training set
plot_defects('non-COVID', 5, 5)

# %%
IMAGE_SIZE = 64
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 2481it [00:39, 63.27it/s]
# Train Shape: (2481, 64, 64, 3)

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=2)

# %%
BATCH_SIZE = 256

# Split the train and validation sets 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 15))
for i in range(3):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(disease_types[np.argmax(Y_train[i])])

# %%
EPOCHS = 50
SIZE=64
N_ch=3

# %%
def build_vgg():
    vgg = VGG19(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = vgg(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    
    # multi output
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    optimizer = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
       
    return model

# %%
model = build_vgg()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('VGG19.h5', verbose=1, save_best_only=True)
# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

datagen.fit(X_train)
# Fits the model on batches with real-time data augmentation
hist = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# C:\Users\chanu\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 3)         84
# _________________________________________________________________
# vgg19 (Functional)           (None, None, None, 512)   20024384
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 2)                 514
# =================================================================
# Total params: 20,159,382
# Trainable params: 20,157,846
# Non-trainable params: 1,536
# _________________________________________________________________
# C:\Users\chanu\anaconda3\lib\site-packages\keras\engine\training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 7/7 - 169s - loss: 1.1670 - accuracy: 0.5469 - val_loss: 0.7148 - val_accuracy: 0.4567
#
# Epoch 00001: val_loss improved from inf to 0.71476, saving model to VGG19.h5
# Epoch 2/50
# 7/7 - 166s - loss: 0.9906 - accuracy: 0.6013 - val_loss: 0.7124 - val_accuracy: 0.5111
#
# Epoch 00002: val_loss improved from 0.71476 to 0.71238, saving model to VGG19.h5
# Epoch 3/50
# 7/7 - 177s - loss: 0.9297 - accuracy: 0.6244 - val_loss: 0.6338 - val_accuracy: 0.6519
#
# Epoch 00003: val_loss improved from 0.71238 to 0.63378, saving model to VGG19.h5
# Epoch 4/50
# 7/7 - 170s - loss: 0.8696 - accuracy: 0.6372 - val_loss: 0.6047 - val_accuracy: 0.6217
#
# Epoch 00004: val_loss improved from 0.63378 to 0.60475, saving model to VGG19.h5
# Epoch 5/50
# 7/7 - 200s - loss: 0.8206 - accuracy: 0.6534 - val_loss: 0.6643 - val_accuracy: 0.5755
#
# Epoch 00005: val_loss did not improve from 0.60475
# Epoch 6/50
# 7/7 - 191s - loss: 0.7491 - accuracy: 0.6811 - val_loss: 0.6199 - val_accuracy: 0.6378
#
# Epoch 00006: val_loss did not improve from 0.60475
# Epoch 7/50
# 7/7 - 1574s - loss: 0.7283 - accuracy: 0.6936 - val_loss: 0.8265 - val_accuracy: 0.5513
#
# Epoch 00007: val_loss did not improve from 0.60475
# Epoch 8/50
# 7/7 - 202s - loss: 0.7074 - accuracy: 0.7054 - val_loss: 0.6978 - val_accuracy: 0.5734
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 00008: val_loss did not improve from 0.60475
# Epoch 9/50
# 7/7 - 223s - loss: 0.7323 - accuracy: 0.6825 - val_loss: 0.6554 - val_accuracy: 0.6117
#
# Epoch 00009: val_loss did not improve from 0.60475
# Epoch 10/50
# 7/7 - 246s - loss: 0.6974 - accuracy: 0.7188 - val_loss: 0.7207 - val_accuracy: 0.5815
#
# Epoch 00010: val_loss did not improve from 0.60475
# Epoch 11/50
# 7/7 - 235s - loss: 0.6451 - accuracy: 0.7240 - val_loss: 0.6087 - val_accuracy: 0.6519
#
# Epoch 00011: val_loss did not improve from 0.60475
# Epoch 12/50
# 7/7 - 227s - loss: 0.6229 - accuracy: 0.7344 - val_loss: 0.5699 - val_accuracy: 0.6720
#
# Epoch 00012: val_loss improved from 0.60475 to 0.56992, saving model to VGG19.h5
# Epoch 13/50
# 7/7 - 233s - loss: 0.6588 - accuracy: 0.7355 - val_loss: 0.7158 - val_accuracy: 0.6298
#
# Epoch 00013: val_loss did not improve from 0.56992
# Epoch 14/50
# 7/7 - 225s - loss: 0.6323 - accuracy: 0.7309 - val_loss: 0.9514 - val_accuracy: 0.5795
#
# Epoch 00014: val_loss did not improve from 0.56992
# Epoch 15/50
# 7/7 - 225s - loss: 0.6373 - accuracy: 0.7234 - val_loss: 0.7654 - val_accuracy: 0.6419
#
# Epoch 00015: val_loss did not improve from 0.56992
# Epoch 16/50
# 7/7 - 226s - loss: 0.6329 - accuracy: 0.7413 - val_loss: 0.5588 - val_accuracy: 0.7183
#
# Epoch 00016: val_loss improved from 0.56992 to 0.55877, saving model to VGG19.h5
# Epoch 17/50
# 7/7 - 224s - loss: 0.5489 - accuracy: 0.7569 - val_loss: 0.5067 - val_accuracy: 0.7545
#
# Epoch 00017: val_loss improved from 0.55877 to 0.50666, saving model to VGG19.h5
# Epoch 18/50
# 7/7 - 230s - loss: 0.6208 - accuracy: 0.7425 - val_loss: 0.9512 - val_accuracy: 0.5915
#
# Epoch 00018: val_loss did not improve from 0.50666
# Epoch 19/50
# 7/7 - 229s - loss: 0.5644 - accuracy: 0.7575 - val_loss: 0.7068 - val_accuracy: 0.6640
#
# Epoch 00019: val_loss did not improve from 0.50666
# Epoch 20/50
# 7/7 - 229s - loss: 0.5905 - accuracy: 0.7598 - val_loss: 0.9670 - val_accuracy: 0.5936
#
# Epoch 00020: val_loss did not improve from 0.50666
# Epoch 21/50
# 7/7 - 234s - loss: 0.5481 - accuracy: 0.7734 - val_loss: 1.0720 - val_accuracy: 0.5835
#
# Epoch 00021: val_loss did not improve from 0.50666
# Epoch 22/50
# 7/7 - 234s - loss: 0.5304 - accuracy: 0.7737 - val_loss: 0.6466 - val_accuracy: 0.6881
#
# Epoch 00022: val_loss did not improve from 0.50666
# Epoch 23/50
# 7/7 - 232s - loss: 0.5269 - accuracy: 0.7795 - val_loss: 0.5465 - val_accuracy: 0.7304
#
# Epoch 00023: val_loss did not improve from 0.50666
# Epoch 24/50
# 7/7 - 233s - loss: 0.5572 - accuracy: 0.7830 - val_loss: 0.9658 - val_accuracy: 0.6097
#
# Epoch 00024: val_loss did not improve from 0.50666
# Epoch 25/50
# 7/7 - 243s - loss: 0.4957 - accuracy: 0.7835 - val_loss: 0.6695 - val_accuracy: 0.6982
#
# Epoch 00025: val_loss did not improve from 0.50666
# Epoch 26/50
# 7/7 - 232s - loss: 0.4937 - accuracy: 0.8015 - val_loss: 1.3279 - val_accuracy: 0.5875
#
# Epoch 00026: val_loss did not improve from 0.50666
# Epoch 27/50
# 7/7 - 225s - loss: 0.5289 - accuracy: 0.7772 - val_loss: 0.5610 - val_accuracy: 0.7565
#
# Epoch 00027: val_loss did not improve from 0.50666
# Epoch 28/50
# 7/7 - 234s - loss: 0.5210 - accuracy: 0.7896 - val_loss: 0.4145 - val_accuracy: 0.8008
#
# Epoch 00028: val_loss improved from 0.50666 to 0.41446, saving model to VGG19.h5
# Epoch 29/50
# 7/7 - 243s - loss: 0.5183 - accuracy: 0.7812 - val_loss: 2.0242 - val_accuracy: 0.5392
#
# Epoch 00029: val_loss did not improve from 0.41446
# Epoch 30/50
# 7/7 - 240s - loss: 0.4936 - accuracy: 0.7986 - val_loss: 0.4065 - val_accuracy: 0.8008
#
# Epoch 00030: val_loss improved from 0.41446 to 0.40652, saving model to VGG19.h5
# Epoch 31/50
# 7/7 - 225s - loss: 0.4723 - accuracy: 0.7998 - val_loss: 0.7351 - val_accuracy: 0.7002
#
# Epoch 00031: val_loss did not improve from 0.40652
# Epoch 32/50
# 7/7 - 238s - loss: 0.4678 - accuracy: 0.8025 - val_loss: 0.3738 - val_accuracy: 0.8249
#
# Epoch 00032: val_loss improved from 0.40652 to 0.37380, saving model to VGG19.h5
# Epoch 33/50
# 7/7 - 230s - loss: 0.4894 - accuracy: 0.7928 - val_loss: 0.4244 - val_accuracy: 0.8008
#
# Epoch 00033: val_loss did not improve from 0.37380
# Epoch 34/50
# 7/7 - 5185s - loss: 0.4543 - accuracy: 0.8092 - val_loss: 0.4139 - val_accuracy: 0.8189
#
# Epoch 00034: val_loss did not improve from 0.37380
# Epoch 35/50

# %%
#model = load_model('../output/kaggle/working/model.h5')
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a5bd091d24af> in <module>
#       1 #model = load_model('../output/kaggle/working/model.h5')
# ----> 2 final_loss, final_accuracy = model.evaluate(X_val, Y_val)
#       3 print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
#
# NameError: name 'model' is not defined

# %%
#model = load_model('../output/kaggle/working/model.h5')
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 16/16 [==============================] - 7s 452ms/step - loss: 0.3346 - accuracy: 0.8732
# Final Loss: 0.33459341526031494, Final Accuracy: 0.8732394576072693

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types, fmt='.2f')
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-537ff0234bec> in <module>
# ----> 1 Y_pred = model.predict(X_val)
#       2
#       3 Y_pred = np.argmax(Y_pred, axis=1)
#       4 Y_true = np.argmax(Y_val, axis=1)
#       5
#
# NameError: name 'model' is not defined

# %%
'''FP = confusion_matrix.sum(axis=0) - np.diag(confusion_matrix)  
FN = confusion_matrix.sum(axis=1) - np.diag(confusion_matrix)
TP = np.diag(confusion_matrix)
TN = confusion_matrix.values.sum() - (FP + FN + TP)'''

TN = cm[0][0]
#print(TN)
FN = cm[1][0]
#print(FN)
TP = cm[1][1]
#print(TP)
FP = cm[0][1]
#print(FP)
# Sensitivity, hit rate, recall, or true positive rate
TPR = TP/(TP+FN)
print(TPR)
# specificity or true negative rate
TNR = TN/(TN+FP)
print(TNR)
# Precision or positive predictive value
PPV = TP/(TP+FP)
# Negative predictive value
NPV = TN/(TN+FN)
# Fall out or false positive rate
FPR = FP/(FP+TN)
# False negative rate
FNR = FN/(TP+FN)
print(FNR)
# False discovery rate
FDR = FP/(TP+FP)

# Overall accuracy
ACC = (TP+TN)/(TP+FP+FN+TN)
print(ACC)
# Out:
# 0.3183856502242152
# 0.9671532846715328
# 0.6816143497757847
# 0.676056338028169

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
 from skimage import io
from keras.preprocessing import image
#path='imbalanced/Scratch/Scratch_400.jpg'
img = image.load_img('C:/Users/chanu/Desktop/covid images/non-COVID/Non-Covid (999).png', grayscale=False, target_size=(64, 64))
show_img=image.load_img('C:/Users/chanu/Desktop/covid images/non-COVID/Non-Covid (999).png', grayscale=False, target_size=(200, 200))
disease_class=['Covid-19','Non Covid-19']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [9.9973565e-01 2.6438350e-04]
# Prediction: Covid-19

# %%
print("training_accuracy", history.history['accuracy'][-1])
print("validation_accuracy", history.history['val_accuracy'][-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0ece0b52d92f> in <module>
# ----> 1 print("training_accuracy", history.history['accuracy'][-1])
#       2 print("validation_accuracy", history.history['val_accuracy'][-1])
#
# NameError: name 'history' is not defined
